# %% [markdown]
# ## Entrenamiento inicial del modelo y búsqueda de hiperparámetros
#
# Para realizar este notebook se utilizó como base el ejemplo presentado en el curso para el dataset "Heart Disease", incluyendo algunas modificaciones para adaptarlo al nuevo dataset "Rain in Australia".
#
# El objetivo de este notebook es realizar experimentos sobre el modelo para luego llevarlo ambiente de producción en caso de que supere ciertas pruebas y además sea aprobado por quien corresponda en la organización.

# %% [markdown]
# Para que el entrenamiento funcione localmente en un tiempo razonable se definió la variable *n_samples_train* que permite indicar qué tamaño tiene el subconjunto a entrenar, de forma de no utilizar todos los datos. Esto debe definirse sólo a modo de prueba para aquellos casos en que no se cuente con los recursos computacionales necesarios para procesar el set completo. En caso de que *n_samples_train* sea 0 se ignorará este parámetro.

# %%
import awswrangler as wr

import mlflow
from mlflow import MlflowClient, MlflowException
from mlflow.models import infer_signature
import optuna

from sklearn.tree import DecisionTreeClassifier

from mlflow_aux import get_or_create_experiment
from optuna_aux import champion_callback, objective
from plots import plot_correlation_with_target, plot_information_gain_with_target, plot_feature_correlation

from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

import random
import datetime

# %env AWS_ACCESS_KEY_ID=minio   
# %env AWS_SECRET_ACCESS_KEY=minio123 
# %env MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# %env AWS_ENDPOINT_URL_S3=http://localhost:9000

# Cantidad de samples a utilizar para el entrenamiento
n_samples_train = 1000
# Out:
# env: AWS_ACCESS_KEY_ID=minio
# env: AWS_SECRET_ACCESS_KEY=minio123
# env: MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# env: AWS_ENDPOINT_URL_S3=http://localhost:9000

# %%
# Se setea URL de seguimiento para MLflow
mlflow_server = "http://localhost:5000"
mlflow.set_tracking_uri(mlflow_server)

# %% [markdown]
# Se cargan los datos de entrenamiento y validación desde el bucket S3. A este punto se asume que ya corrió sin errores el DAG *etl_process_rain_australia*, haciendo las transformaciones necesarias de los datos.

# %%
# Se cargan los conjuntos de entrenamiento y validación.

X_train =  wr.s3.read_csv("s3://data/final/train/weather_X_train.csv")
y_train =  wr.s3.read_csv("s3://data/final/train/weather_y_train.csv")

X_test =  wr.s3.read_csv("s3://data/final/test/weather_X_test.csv")
y_test =  wr.s3.read_csv("s3://data/final/test/weather_y_test.csv")

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106644 entries, 0 to 106643
# Data columns (total 28 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   MinTemp          106644 non-null  float64
#  1   MaxTemp          106644 non-null  float64
#  2   Rainfall         106644 non-null  float64
#  3   Evaporation      106644 non-null  float64
#  4   Sunshine         106644 non-null  float64
#  5   WindGustSpeed    106644 non-null  float64
#  6   WindSpeed9am     106644 non-null  float64
#  7   WindSpeed3pm     106644 non-null  float64
#  8   Humidity9am      106644 non-null  float64
#  9   Humidity3pm      106644 non-null  float64
#  10  Pressure9am      106644 non-null  float64
#  11  Pressure3pm      106644 non-null  float64
#  12  Cloud9am         106644 non-null  float64
#  13  Cloud3pm         106644 non-null  float64
#  14  Temp9am          106644 non-null  float64
#  15  Temp3pm          106644 non-null  float64
#  16  RainToday        106644 non-null  float64
#  17  Year             106644 non-null  float64
#  18  Month            106644 non-null  float64
#  19  Day              106644 non-null  float64
#  20  Latitude         106644 non-null  float64
#  21  Longitude        106644 non-null  float64
#  22  WindGustDir_sin  106644 non-null  float64
#  23  WindGustDir_cos  106644 non-null  float64
#  24  WindDir9am_sin   106644 non-null  float64
#  25  WindDir9am_cos   106644 non-null  float64
#  26  WindDir3pm_sin   106644 non-null  float64
#  27  WindDir3pm_cos   106644 non-null  float64
# dtypes: float64(28)
# memory usage: 22.8 MB

# %% [markdown]
# Previo a la elaboración del DAG *etl_process_rain_australia* ya se realizó un análisis y limpieza del dataset en el que, entre otras acciones, se determinó las correlación entre las variables de entrada y de éstas con la variable objetivo. De todas formas, es útil registrar esta información para observar en el tiempo los posibles cambios que se puedan producir.

# %%
# Se obtienen los gráficos correspondientes a las correlaciones
correlation_plot = plot_correlation_with_target(X_train, y_train, target_col='RainTomorrow')
information_gain_plot = plot_information_gain_with_target(X_train, y_train, target_col='RainTomorrow')
features_correlation_plot = plot_feature_correlation(X_train)

# %% [markdown]
# Las diferentes ejecuciones de entrenamiento quedarán registradas en el experimento "Rain in Australia". El tuneo de hiperparámetros se mostrará como un *run* dentro de este experimentos que a su vez contendrá *runs* hijos correspondientes a cada prueba (*trial*) realizada.

# %%
experiment_id = get_or_create_experiment("Rain in Australia")
print(experiment_id)

run_name_parent = "best_hyperparam_"  + datetime.datetime.today().strftime('%Y/%m/%d-%H:%M:%S"')
# Out:
# 1

# %% [markdown]
# Tal como se comentó al comienzo, en caso de estar definida la variable *n_samples_train* se tomará un subconjunto de datos. La idea de utilizar esto es sólo para pruebas en equipos con bajos recursos computacionales.

# %%
if n_samples_train > 0:

    indices = random.sample(range(len(X_train)), n_samples_train)

    X_train = X_train.iloc[indices].reset_index(drop=True)
    y_train = y_train.iloc[indices].reset_index(drop=True)

# %% [markdown]
# Se realiza la optimización usan Optuna. Además, como se indicó anteriormente, se reutilizaron las librerías del ejemplo proporcionado en el curso dado que simplifican mucho la tarea y proporcionan una base sólida para futuras mejoras.

# %%
with mlflow.start_run(experiment_id=experiment_id, run_name=run_name_parent, nested=True):
    # Inicializamos el estudio de Optuna
    study = optuna.create_study(direction="maximize")

    # Ejecutamos los trials de optimización de hiperparametros. Cada uno de estos trials se ejecuta con un run separado, pero 
    # está anidado al run padre.
    # Notar la adición del `champion_callback` para controlar qué mensajes mostramos
    # Para entender mejor esto ver la documentación de objective y champion_callback en optuna_aux
    study.optimize(lambda trial: objective(trial, X_train, y_train, experiment_id), n_trials=250, callbacks=[champion_callback])

    # Una vez que terminamos la búsqueda, guardamos los mejores parámetros en el run padre.
    mlflow.log_params(study.best_params)
    mlflow.log_metric("best_train_f1", study.best_value)

    mlflow.set_tags(
        tags={
            "project": "Rain in Australia",
            "optimizer_engine": "optuna",
            "model_family": "sklearn",
            "feature_set_version": 1,
        }
    )

    # Una vez que terminamos la búsqueda, nos quedamos con el mejor modelo y lo entrenamos
    if study.best_params["classifier"] == "SVC_linear":
        model = SVC(C=study.best_params["svc_c"], kernel='linear', gamma='scale')
    elif study.best_params["classifier"] == "SVC_poly":
        model = SVC(C=study.best_params["svc_c"], kernel='poly', 
                    gamma='scale', degree=study.best_params["svc_poly_degree"])
    elif study.best_params["classifier"] == "SVC_rbf":
        model = SVC(C=study.best_params["svc_c"], kernel='rbf', gamma='scale')
    elif study.best_params["classifier"] == "DecisionTreeClassifier":
        model = DecisionTreeClassifier(max_depth=study.best_params["tree_max_depth"])
    else:
        model = RandomForestClassifier(max_depth=study.best_params["rf_max_depth"], 
                                       n_estimators=study.best_params["rf_n_estimators"])

    model = model.fit(X_train, y_train.to_numpy().ravel())

    # Y testeamos el modelo y logueamos el resultado
    y_pred = model.predict(X_test)
    f1_score = f1_score(y_test.to_numpy().ravel(), y_pred)
    mlflow.log_metric("test_f1", f1_score)

    # Logueamos los artefactos de las gráficas de correlación y de information_gain
    mlflow.log_figure(figure=correlation_plot, artifact_file="correlation_plot.png")
    mlflow.log_figure(figure=information_gain_plot, artifact_file="information_gain_plot.png")
    mlflow.log_figure(features_correlation_plot, artifact_file="features_correlation_plot.png")

    # Guardamos el artefacto del modelo
    artifact_path = "model"

    signature = infer_signature(X_train, model.predict(X_train))

    mlflow.sklearn.log_model(
        sk_model=model,
        artifact_path=artifact_path,
        signature=signature,
        serialization_format='cloudpickle',
        registered_model_name="rain_australia_model_dev",
        metadata={"model_data_version": 1}
    )

    # Obtenemos la ubicación del modelo guardado en MLFlow
    model_uri = mlflow.get_artifact_uri(artifact_path)
# Out:
# [I 2024-08-24 18:33:39,444] A new study created in memory with name: no-name-eaffba1f-7335-4b56-909b-b00e39598f93
# 2024/08/24 18:33:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 0 at: http://localhost:5000/#/experiments/1/runs/99fc7b7cafbd422b8661c17f1eacaedf.
# 2024/08/24 18:33:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:33:52,898] Trial 0 finished with value: 0.4602099530519091 and parameters: {'classifier': 'SVC_rbf', 'svc_c': 53.17915624621662}. Best is trial 0 with value: 0.4602099530519091.
# Initial trial 0 achieved value: 0.4602099530519091
# 2024/08/24 18:33:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 1 at: http://localhost:5000/#/experiments/1/runs/2e29a9b006a1410aab9bedad4cd9d93c.
# 2024/08/24 18:33:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:33:53,455] Trial 1 finished with value: 0.5054419635157734 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.2971184033131538}. Best is trial 1 with value: 0.5054419635157734.
# Trial 1 achieved value: 0.5054419635157734 with  8.9490% improvement
# 2024/08/24 18:33:54 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 2 at: http://localhost:5000/#/experiments/1/runs/147c81629561479b8110270861be11f7.
# 2024/08/24 18:33:54 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:33:54,134] Trial 2 finished with value: 0.0 and parameters: {'classifier': 'SVC_rbf', 'svc_c': 0.05786627489993669}. Best is trial 1 with value: 0.5054419635157734.
# 2024/08/24 18:33:54 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 3 at: http://localhost:5000/#/experiments/1/runs/bb6b233d50174462a86c919b828e6550.
# 2024/08/24 18:33:54 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:33:55,014] Trial 3 finished with value: 0.3927337382875125 and parameters: {'classifier': 'DecisionTreeClassifier', 'tree_max_depth': 5}. Best is trial 1 with value: 0.5054419635157734.
# 2024/08/24 18:33:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 4 at: http://localhost:5000/#/experiments/1/runs/9e168029fbac46afbfdb61a218e42fdb.
# 2024/08/24 18:33:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:33:56,070] Trial 4 finished with value: 0.3993060031059313 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 5, 'rf_n_estimators': 2}. Best is trial 1 with value: 0.5054419635157734.
# 2024/08/24 18:33:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 5 at: http://localhost:5000/#/experiments/1/runs/62ece65f6113499fad9b3fea06788b78.
# 2024/08/24 18:33:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:33:56,874] Trial 5 finished with value: 0.0 and parameters: {'classifier': 'SVC_rbf', 'svc_c': 0.15632721766119975}. Best is trial 1 with value: 0.5054419635157734.
# 2024/08/24 18:34:04 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 6 at: http://localhost:5000/#/experiments/1/runs/389d553b434b4b849267a16907651b89.
# 2024/08/24 18:34:04 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:04,377] Trial 6 finished with value: 0.5090506613824402 and parameters: {'classifier': 'SVC_linear', 'svc_c': 27.145736031280176}. Best is trial 6 with value: 0.5090506613824402.
# Trial 6 achieved value: 0.5090506613824402 with  0.7089% improvement
# 2024/08/24 18:34:04 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 7 at: http://localhost:5000/#/experiments/1/runs/61f64bb12c324e65a5d8cb979a95e6ff.
# 2024/08/24 18:34:04 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:04,994] Trial 7 finished with value: 0.0 and parameters: {'classifier': 'SVC_poly', 'svc_c': 0.0677252485724123, 'svc_poly_degree': 2}. Best is trial 6 with value: 0.5090506613824402.
# 2024/08/24 18:34:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 8 at: http://localhost:5000/#/experiments/1/runs/88a576cc60be42b183db2546d6d0b8ef.
# 2024/08/24 18:34:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:05,463] Trial 8 finished with value: 0.39208897350425487 and parameters: {'classifier': 'DecisionTreeClassifier', 'tree_max_depth': 5}. Best is trial 6 with value: 0.5090506613824402.
# 2024/08/24 18:34:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 9 at: http://localhost:5000/#/experiments/1/runs/676087327836456683345c417559fea5.
# 2024/08/24 18:34:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:05,991] Trial 9 finished with value: 0.3874037162243387 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 10, 'rf_n_estimators': 4}. Best is trial 6 with value: 0.5090506613824402.
# 2024/08/24 18:34:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 10 at: http://localhost:5000/#/experiments/1/runs/00c92a1f09b542b0bc0ac6303cc1c8dd.
# 2024/08/24 18:34:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:08,700] Trial 10 finished with value: 0.5090506613824402 and parameters: {'classifier': 'SVC_linear', 'svc_c': 15.766367836695833}. Best is trial 6 with value: 0.5090506613824402.
# 2024/08/24 18:34:14 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 11 at: http://localhost:5000/#/experiments/1/runs/9be46c1ff9d343e2ad8c5352eef514bf.
# 2024/08/24 18:34:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:14,462] Trial 11 finished with value: 0.5090506613824402 and parameters: {'classifier': 'SVC_linear', 'svc_c': 20.705912404400056}. Best is trial 6 with value: 0.5090506613824402.
# 2024/08/24 18:34:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 12 at: http://localhost:5000/#/experiments/1/runs/36baa0ebc0b54f9eb7ce4bf6a8ebdffc.
# 2024/08/24 18:34:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:16,101] Trial 12 finished with value: 0.5090506613824402 and parameters: {'classifier': 'SVC_linear', 'svc_c': 3.9567057712104168}. Best is trial 6 with value: 0.5090506613824402.
# 2024/08/24 18:34:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 13 at: http://localhost:5000/#/experiments/1/runs/6fd41d41b19543b5a37cc183878608ea.
# 2024/08/24 18:34:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:17,497] Trial 13 finished with value: 0.5090506613824402 and parameters: {'classifier': 'SVC_linear', 'svc_c': 4.650388427296459}. Best is trial 6 with value: 0.5090506613824402.
# 2024/08/24 18:34:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 14 at: http://localhost:5000/#/experiments/1/runs/c81a95dd18144374bece1acdb76f181b.
# 2024/08/24 18:34:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:45,834] Trial 14 finished with value: 0.5078203127836705 and parameters: {'classifier': 'SVC_linear', 'svc_c': 92.64907905678473}. Best is trial 6 with value: 0.5090506613824402.
# 2024/08/24 18:34:46 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 15 at: http://localhost:5000/#/experiments/1/runs/fed9601c3c6b4f8eaf7a85a885d44427.
# 2024/08/24 18:34:46 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:46,688] Trial 15 finished with value: 0.3185810080034609 and parameters: {'classifier': 'SVC_poly', 'svc_c': 7.620676351310861, 'svc_poly_degree': 6}. Best is trial 6 with value: 0.5090506613824402.
# 2024/08/24 18:34:47 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 16 at: http://localhost:5000/#/experiments/1/runs/570fa2d373814715b6dbae02f51e21ee.
# 2024/08/24 18:34:47 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:47,557] Trial 16 finished with value: 0.5104138551506973 and parameters: {'classifier': 'SVC_linear', 'svc_c': 1.0110991279794062}. Best is trial 16 with value: 0.5104138551506973.
# Trial 16 achieved value: 0.5104138551506973 with  0.2671% improvement
# 2024/08/24 18:34:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 17 at: http://localhost:5000/#/experiments/1/runs/8a1c87910aff4dc79b5dbd31c4c455e7.
# 2024/08/24 18:34:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:48,171] Trial 17 finished with value: 0.44375732269388984 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.01388673778958273}. Best is trial 16 with value: 0.5104138551506973.
# 2024/08/24 18:34:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 18 at: http://localhost:5000/#/experiments/1/runs/7496e983cdbd42a89761724a92cecddf.
# 2024/08/24 18:34:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:49,159] Trial 18 finished with value: 0.5104138551506973 and parameters: {'classifier': 'SVC_linear', 'svc_c': 1.0826260515354362}. Best is trial 16 with value: 0.5104138551506973.
# 2024/08/24 18:34:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 19 at: http://localhost:5000/#/experiments/1/runs/0d27203444014257a85453d0813d8015.
# 2024/08/24 18:34:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:49,800] Trial 19 finished with value: 0.26964362005735165 and parameters: {'classifier': 'SVC_poly', 'svc_c': 0.8498347155821598, 'svc_poly_degree': 4}. Best is trial 16 with value: 0.5104138551506973.
# 2024/08/24 18:34:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 20 at: http://localhost:5000/#/experiments/1/runs/68c3de7e08c24c878db405f803fb9cbb.
# 2024/08/24 18:34:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:50,618] Trial 20 finished with value: 0.41855954821872327 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 28, 'rf_n_estimators': 10}. Best is trial 16 with value: 0.5104138551506973.
# 2024/08/24 18:34:51 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 21 at: http://localhost:5000/#/experiments/1/runs/6fc6d770db4647179a13ed92859457da.
# 2024/08/24 18:34:51 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:51,684] Trial 21 finished with value: 0.5104138551506973 and parameters: {'classifier': 'SVC_linear', 'svc_c': 1.6669649845037184}. Best is trial 16 with value: 0.5104138551506973.
# 2024/08/24 18:34:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 22 at: http://localhost:5000/#/experiments/1/runs/87bd34407c974467840d1a332e666d8c.
# 2024/08/24 18:34:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:52,764] Trial 22 finished with value: 0.5090506613824402 and parameters: {'classifier': 'SVC_linear', 'svc_c': 1.617670835246873}. Best is trial 16 with value: 0.5104138551506973.
# 2024/08/24 18:34:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 23 at: http://localhost:5000/#/experiments/1/runs/e3245c724f704ce2b4d0a231c8fc11eb.
# 2024/08/24 18:34:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:34:53,644] Trial 23 finished with value: 0.5104138551506973 and parameters: {'classifier': 'SVC_linear', 'svc_c': 1
INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 66 at: http://localhost:5000/#/experiments/1/runs/599d4ec0172f41d1bc0f97e394c71804.
# 2024/08/24 18:35:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:14,515] Trial 66 finished with value: 0.5093675072148015 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.7932563462894435}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 67 at: http://localhost:5000/#/experiments/1/runs/447238d84c8149af843ec0be80006ae0.
# 2024/08/24 18:35:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:15,281] Trial 67 finished with value: 0.19829526646805692 and parameters: {'classifier': 'SVC_poly', 'svc_c': 0.3185625885962585, 'svc_poly_degree': 4}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 68 at: http://localhost:5000/#/experiments/1/runs/957c4771067948c2ba88b0228f258b4b.
# 2024/08/24 18:35:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:16,071] Trial 68 finished with value: 0.5120688059161003 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.4910497288923902}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 69 at: http://localhost:5000/#/experiments/1/runs/29653bf0e7fd477c836f2b4c76cf6ee6.
# 2024/08/24 18:35:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:17,214] Trial 69 finished with value: 0.5090506613824402 and parameters: {'classifier': 'SVC_linear', 'svc_c': 2.050071758160052}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:19 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 70 at: http://localhost:5000/#/experiments/1/runs/1118bab95d1048058db55f18f7834ee8.
# 2024/08/24 18:35:19 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:19,468] Trial 70 finished with value: 0.5090506613824402 and parameters: {'classifier': 'SVC_linear', 'svc_c': 5.123748420228071}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 71 at: http://localhost:5000/#/experiments/1/runs/2b4089300e6f46d99a773bd1dc95e284.
# 2024/08/24 18:35:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:20,212] Trial 71 finished with value: 0.5120688059161003 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.5183332882651497}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 72 at: http://localhost:5000/#/experiments/1/runs/3f3f258c84c44ca194dab979f29c8d8f.
# 2024/08/24 18:35:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:21,083] Trial 72 finished with value: 0.5107033687771787 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.400041887781042}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 73 at: http://localhost:5000/#/experiments/1/runs/c8d97835c7654685b61528992b0c9c48.
# 2024/08/24 18:35:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:21,995] Trial 73 finished with value: 0.5104138551506973 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.9853391867333796}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 74 at: http://localhost:5000/#/experiments/1/runs/4e1b1509270e49a6a865be9b6b7a3e19.
# 2024/08/24 18:35:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:22,727] Trial 74 finished with value: 0.5068051572840305 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.18284537720453645}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 75 at: http://localhost:5000/#/experiments/1/runs/53ef270239f7407782eb1b0de66fa29b.
# 2024/08/24 18:35:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:23,603] Trial 75 finished with value: 0.5054419635157734 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.301730932073239}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 76 at: http://localhost:5000/#/experiments/1/runs/e3da5d224eb14725a0523b87e2fb7f2e.
# 2024/08/24 18:35:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:24,164] Trial 76 finished with value: 0.44694104492845027 and parameters: {'classifier': 'SVC_rbf', 'svc_c': 0.8395015623520928}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 77 at: http://localhost:5000/#/experiments/1/runs/dbfbf1fc575f4af8be7b06dfbee29a1e.
# 2024/08/24 18:35:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:24,903] Trial 77 finished with value: 0.5104138551506973 and parameters: {'classifier': 'SVC_linear', 'svc_c': 1.287712778294193}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 78 at: http://localhost:5000/#/experiments/1/runs/e2feb308c4444b9488f75ee8730ba8fd.
# 2024/08/24 18:35:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:25,210] Trial 78 finished with value: 0.3701283957674061 and parameters: {'classifier': 'DecisionTreeClassifier', 'tree_max_depth': 2}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 79 at: http://localhost:5000/#/experiments/1/runs/6812fa6d4b7e4bb398dbc7b930e9da3c.
# 2024/08/24 18:35:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:25,619] Trial 79 finished with value: 0.3767278355969926 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 9, 'rf_n_estimators': 6}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 80 at: http://localhost:5000/#/experiments/1/runs/e91cf8161178414da7377cddf4311c25.
# 2024/08/24 18:35:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:33,378] Trial 80 finished with value: 0.5078203127836705 and parameters: {'classifier': 'SVC_linear', 'svc_c': 44.56824501340588}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 81 at: http://localhost:5000/#/experiments/1/runs/4fd368fe059d4f3d854bcf395c6022ce.
# 2024/08/24 18:35:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:33,756] Trial 81 finished with value: 0.5120688059161003 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.5140281650892623}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 82 at: http://localhost:5000/#/experiments/1/runs/0f4ca0c217ae4442a42ab1fe546ff39b.
# 2024/08/24 18:35:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:34,202] Trial 82 finished with value: 0.5120688059161003 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.48816760682564114}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 83 at: http://localhost:5000/#/experiments/1/runs/ea4f52024f4d4f5fa24629deece4e4b0.
# 2024/08/24 18:35:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:34,648] Trial 83 finished with value: 0.5055713034185977 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.6443933634231446}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:35 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 84 at: http://localhost:5000/#/experiments/1/runs/4d222a662d0e4f0fa17e94636f89a14e.
# 2024/08/24 18:35:35 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:35,071] Trial 84 finished with value: 0.5054419635157734 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.26700008297315436}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:35 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 85 at: http://localhost:5000/#/experiments/1/runs/fb6a3c1e306041248141e8fc0eb5c47d.
# 2024/08/24 18:35:35 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:35,570] Trial 85 finished with value: 0.5067739648477747 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.3857870863471709}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:35 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 86 at: http://localhost:5000/#/experiments/1/runs/40a60620f4d14956883ae682cffdaab0.
# 2024/08/24 18:35:35 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:36,004] Trial 86 finished with value: 0.16500110987791342 and parameters: {'classifier': 'SVC_poly', 'svc_c': 0.13030078760674457, 'svc_poly_degree': 5}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 87 at: http://localhost:5000/#/experiments/1/runs/7f40c7975f3b489baf4a22d343f093b2.
# 2024/08/24 18:35:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:36,517] Trial 87 finished with value: 0.5120688059161003 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.5137124486711666}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 88 at: http://localhost:5000/#/experiments/1/runs/d09a55f12198472b8f885843e2fd1b82.
# 2024/08/24 18:35:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:36,939] Trial 88 finished with value: 0.5002678993783516 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.09096510279656114}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 89 at: http://localhost:5000/#/experiments/1/runs/1eb4d3c5f5954acb89bba226021e1360.
# 2024/08/24 18:35:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:37,469] Trial 89 finished with value: 0.5067739648477747 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.3527336842797385}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:38 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 90 at: http://localhost:5000/#/experiments/1/runs/ceb64e60609b424e83c5f5ec34f78dba.
# 2024/08/24 18:35:38 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:38,288] Trial 90 finished with value: 0.510313819277177 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.9431857998061038}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:38 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 91 at: http://localhost:5000/#/experiments/1/runs/11c7fb0b944344e2862910f7d17da3dd.
# 2024/08/24 18:35:38 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:38,977] Trial 91 finished with value: 0.5120688059161003 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.5356263394501527}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 92 at: http://localhost:5000/#/experiments/1/runs/feae5ff5f337485baed0363f39fae739.
# 2024/08/24 18:35:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:39,943] Trial 92 finished with value: 0.5093675072148015 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.7587112655672935}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 93 at: http://localhost:5000/#/experiments/1/runs/286645565cb44978b15b30263580ebee.
# 2024/08/24 18:35:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:35:40,652] Trial 93 finished with value: 0.5068051572840305 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.17797932095715469}. Best is trial 24 with value: 0.5120688059161003.
# 2024/08/24 18:35:41 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial:
INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 247 at: http://localhost:5000/#/experiments/1/runs/0ef3b035a1084d26aa98829b70c06bfe.
# 2024/08/24 18:37:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:37:33,378] Trial 247 finished with value: 0.5133675072148016 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.5670085460200512}. Best is trial 104 with value: 0.5133675072148016.
# 2024/08/24 18:37:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 248 at: http://localhost:5000/#/experiments/1/runs/6fa7ccf1fa894be38ccffaae4a7484f2.
# 2024/08/24 18:37:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:37:33,871] Trial 248 finished with value: 0.5093675072148015 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.8700696917921791}. Best is trial 104 with value: 0.5133675072148016.
# 2024/08/24 18:37:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run Trial: 249 at: http://localhost:5000/#/experiments/1/runs/4a647dc8a2194b54aeed586c74866f18.
# 2024/08/24 18:37:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# [I 2024-08-24 18:37:34,508] Trial 249 finished with value: 0.5093675072148015 and parameters: {'classifier': 'SVC_linear', 'svc_c': 0.5877010768635886}. Best is trial 104 with value: 0.5133675072148016.
# Registered model 'rain_australia_model_dev' already exists. Creating a new version of this model...
# 2024/08/24 18:37:51 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: rain_australia_model_dev, version 3
# Created version '3' of model 'rain_australia_model_dev'.
# 2024/08/24 18:37:51 INFO mlflow.tracking._tracking_service.client: 🏃 View run best_hyperparam_2024/08/24-18:33:39" at: http://localhost:5000/#/experiments/1/runs/3f92d100e6404de08a1c3cce304f8e15.
# 2024/08/24 18:37:51 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.

# %% [markdown]
# Una vez entrenado el modelo, en este punto se deberían realizar diferentes pruebas para validar que se encuentre en condiciones de ser puesto en producción. Una vez recibida la aprobación, se deberían ejecutar los siguientes pasos para promover el modelo.

# %%
client = MlflowClient()

# %%
# Se define el nombre del modelo y su descripción
name = "rain_australia_model_prod"
desc = "This classifier predicts whether it will rain tomorrow"

# %% [markdown]
# En caso que no sea la primera vez que se corre este notebook y ya existe un modelo en producción, se elimina el modelo anterior antes de crear el nuevo.

# %%
try:
    # Intenta obtener el modelo registrado por nombre
    registered_model = client.get_registered_model(name=name)
    
    # Si se encuentra, procede a eliminarlo
    client.delete_registered_model(name=name)
    print(f"El modelo '{name}' ha sido eliminado.")
    
except MlflowException as e:
    # Captura la excepción si el modelo no existe
    if "RESOURCE_DOES_NOT_EXIST" in str(e):
        print(f"El modelo '{name}' no existe. No se realizó ninguna acción.")
    else:
        # Si es otra excepción, la relanza
        raise
# Out:
# El modelo 'rain_australia_model_prod' ha sido eliminado.

# %% [markdown]
# Se crea el modelo productivo en MLflow. Se le asigna el alias "champion" que indica que es el mejor hasta el momento, pero que eventualmente podría ser sustituido por otro modelo "challenger" entrenado en el dag *train_model_rain_australia* agendado en Airflow. En este modelo se almacenan como tags los metadatos del mismo así como también el resultado de la métrica *f1-score*.

# %%
# Creamos el modelo productivo
client.create_registered_model(name=name, description=desc)

# Guardamos como tag los hiper-parametros en la version del modelo
tags = model.get_params()
tags["model"] = type(model).__name__
tags["f1-score"] = f1_score

# Guardamos la version del modelo
result = client.create_model_version(
    name=name,
    source=model_uri,
    run_id=model_uri.split("/")[-3],
    tags=tags
)

# Y creamos como la version con el alias de champion para poder levantarlo en nuestro
# proceso de servicio del modelo on-line.
client.set_registered_model_alias(name, "champion", result.version)
# Out:
# 2024/08/24 18:37:52 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: rain_australia_model_prod, version 1
